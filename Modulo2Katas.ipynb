# %% [markdown]
# # Kata 2 Capturas de pantalla

# %%
from IPython.display import Image

# %% [markdown]
# Creando el entorno virutal kata2

# %%
Image("./img/1.PNG")

# %% [markdown]
# Activamos el entorno virtual

# %%
Image("./img/2.PNG")

# %% [markdown]
# Comprobamos los paquetes instalados en el entorno virtual

# %%
Image("./img/3.PNG")

# %% [markdown]
# Instalamos el paquete Python-dateutil

# %%
Image("./img/4.PNG")

# %% [markdown]
# Mostramos los paquetes instalados en el entorno virtual con el comando freeze

# %%
Image("./img/5.PNG")

# %% [markdown]
# Desactivamos el entorno virtual

# %%
Image("./img/6.PNG")

# %% [markdown]
# Carpeteras creadas en el entorno virtual

# %%
Image("./img/7.PNG")
