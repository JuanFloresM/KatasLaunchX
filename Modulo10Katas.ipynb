# %% [markdown]
# # Kata 10

# %%
from IPython.display import Image
Image("./img/9.PNG")
#Abriendo un archivo inexistente
#open("./mars.jpg")

# %% [markdown]
# Creando el archivo open.py con el código especificado en la Kata

# %%
from IPython.display import Image
Image("./img/8.PNG")

# %% [markdown]
# Abriendo el archivo en la terminal

# %%
Image("./img/10.PNG")

# %% [markdown]
# Try y Except de los bloques

# %%
try:
    open('./config.tx')
except FileNotFoundError:
    print("Couldn't find the config.txt file!")
# Out:
# Couldn't find the config.txt file!

# %% [markdown]
# Creando el archivo config.py

# %%
Image("./img/12.PNG")

# %% [markdown]
# creamos el directorio config.txt

# %%
Image("img/12.PNG")

# %% [markdown]
# Ejecutamos el archivo config.py

# %%
Image("./img/13.PNG")

# %% [markdown]
# Actualizamos el main de config.py

# %%
Image("./img/14.PNG")

# %% [markdown]
# Ejecutamos el archivo config.py

# %%
Image("./img/15.PNG")

# %% [markdown]
# Volvemos a actualizar el archivo config.py

# %%
Image("./img/16.PNG")

# %% [markdown]
# Volvemos a ejecutar el programa config.py

# %%
Image("./img/17.PNG")

# %% [markdown]
# Eliminamos el archivo config.txt y ejecutamos config.py

# %%
Image("./img/18.PNG")

# %% [markdown]
# Modificamos el archivo config.py

# %%
Image("./img/19.PNG")

# %% [markdown]
# Ejecutamos el archivo config.py

# %%
Image("./img/20.PNG")

# %% [markdown]
# Creamos una función para calcular la cantidad de agua que quedará después de un día o más.

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
#probamos el metodo
water_left(5,100,2)
# Out:
# 'Total water left after 2 days is: -10 liters'

# %% [markdown]
# Modificamos la función water_left

# %%
def water_left(astronauts, water_left, days_left):
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
#Probamos la excepción
water_left(5,100,2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12372/1081449767.py in <module>
#       1 #Probamos la excepción
# ----> 2 water_left(5,100,2)
#
# ~\AppData\Local\Temp/ipykernel_12372/560898979.py in water_left(astronauts, water_left, days_left)
#       4     total_water_left = water_left - total_usage
#       5     if total_water_left < 0:
# ----> 6         raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
#       7     return f"Total water left after {days_left} days is: {total_water_left} liters"
#
# RuntimeError: There is not enough water for 5 astronauts after 2 days!

# %%
#Generamos una alerta
try:
    water_left(5, 100, 2)
except RuntimeError as err:
    print(err)
# Out:
# There is not enough water for 5 astronauts after 2 days!

# %%
#probamos con datos no admitidos
water_left("3", "200", None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12372/2422974602.py in <module>
# ----> 1 water_left("3", "200", None)
#
# ~\AppData\Local\Temp/ipykernel_12372/560898979.py in water_left(astronauts, water_left, days_left)
#       1 def water_left(astronauts, water_left, days_left):
#       2     daily_usage = astronauts * 11
# ----> 3     total_usage = daily_usage * days_left
#       4     total_water_left = water_left - total_usage
#       5     if total_water_left < 0:
#
# TypeError: can't multiply sequence by non-int of type 'NoneType'

# %% [markdown]
# Modificamos la función water_left

# %%
def water_left(astronauts, water_left, days_left):
    for argument in [astronauts, water_left, days_left]:
        try:
            # If argument is an int, the following operation will work
            argument / 10
        except TypeError:
            # TypError will be raised only if it isn't the right type 
            # Raise the same exception but with a better error message
            raise TypeError(f"All arguments must be of type int, but received: '{argument}'")
    daily_usage = astronauts * 11
    total_usage = daily_usage * days_left
    total_water_left = water_left - total_usage
    if total_water_left < 0:
        raise RuntimeError(f"There is not enough water for {astronauts} astronauts after {days_left} days!")
    return f"Total water left after {days_left} days is: {total_water_left} liters"

# %%
#Volvemos a ejecutar el metodo con datos no permitidos
water_left("3", "200", None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12372/687367909.py in water_left(astronauts, water_left, days_left)
#       4             # If argument is an int, the following operation will work
# ----> 5             argument / 10
#       6         except TypeError:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12372/3525685593.py in <module>
#       1 #Volvemos a ejecutar el metodo con datos no permitidos
# ----> 2 water_left("3", "200", None)
#
# ~\AppData\Local\Temp/ipykernel_12372/687367909.py in water_left(astronauts, water_left, days_left)
#       7             # TypError will be raised only if it isn't the right type
# ...
